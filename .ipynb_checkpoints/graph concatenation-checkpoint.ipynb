# %% [markdown]
# # The creation of the giant graph

# %%
import logging

logger = logging.getLogger('requests_throttler')
logger.addHandler(logging.NullHandler())
logger.propagate = False

# %%
from graph_builder import *
# Out:
# done

# %%
# %matplotlib inline


for sent in sents[:3]:
    test_tree_build
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-c9512f070f85> in <module>()
#       9     l = []
#      10     sent =  l.append(sent)
# ---> 11     G.gen_data(sent)
#      12     giant_graph = G.gen_giant_graph()
#      13     G.plot_graph(giant_graph)
#
# /home/master/Desktop/GIT/syntax_embeddings/document_embeddings/graph_builder.py in gen_data(self, sents)
#      75 		"""
#      76                 self.sents = sents
# ---> 77                 tokenised_sents = [[word for word in sent.split()] for sent in sents]
#      78
#      79                 for sent in tokenised_sents:
#
# TypeError: 'NoneType' object is not iterable

# %%
G.gen_data(sents)
giant_graph = G.gen_giant_graph()

# %%
# %matplotlib inline

G.plot_graph(giant_graph)
